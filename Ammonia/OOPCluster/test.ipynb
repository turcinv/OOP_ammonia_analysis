# %%
from oop_cluster_copy import AmmoniaCluster

# %%
ammonia = AmmoniaCluster(21)

# %%
ammonia.cp2k_input("ammonia-02-1", "12", "hovno.inp", 500, 12, 12, 0, 1, 12)

# %%
ammonia.__str__()
# Out:
# 'ID of cluster: 21, Number of ammonia: 2, Folder: None'

# %%
ammonia.plot_rdf()

# %%
print(ammonia.get_value_from_key())
# Out:
# (2, '02', 1)

# %%
ammonia.ener_to_csv()

# %%
ammonia.four_plots_in_one()
# Out:
# Generated in:
# 	Thu Apr 20 08:58:22 2023

# %%
cluster_id = [21, 22, 34, 41, 42, 44, 51, 54, 62, 71, 81, 82, 83]
cluster = {}

for i in cluster_id:
  cluster[i] = AmmoniaCluster(i)

# print(cluster)

cluster[21].get_properties()
cluster[22].get_properties()
# Out:
# 'Properties computing 22 from TXT file'

# %%
from oop_cluster import AmmoniaCluster
ammonia = AmmoniaCluster(cluster_id=21)

print(ammonia.get_value_from_key())
print(ammonia.make_bash())
ammonia.generate_rdf()
print(ammonia.control_logs())
print(ammonia.ener_to_csv())
print(ammonia.average_used_time())
print(ammonia.graph_ener())
ammonia.four_plots_in_one()
print(ammonia.cp2k_input())
print(ammonia.get_properties())
print(ammonia.make_grid())
print(ammonia)
# Out:
# ('02', 1)
# This method makes SH input of 21
# This method control LOG file of 21
# This method makes CSV file from ENER file of 21
# Average time per step is 48.38 s
# None
# This method makes interactive plot of 21
# Generated in:
# 	Thu Apr 20 08:58:25 2023
# This method makes INP file of 21
# Properties computing ammonia {self.cluster_id} from TXT file
# This method makes XYZ file with ghost atoms of 21
# ID of cluster: 21, Number of ammonia: 0, Folder: None
